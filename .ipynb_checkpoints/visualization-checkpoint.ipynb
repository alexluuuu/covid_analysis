# %%
import numpy as np
import os 
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import pickle 


# %matplotlib inline

# %%
def read_from_file(name):
    '''
        Return loaded object given by input name
    '''
    print 'reading structures from pickle'
    print '------------------------------'

    path = os.getcwd() + '/pickles/' + name + '.pkl'
    file = open(path, 'rb')
    new_obj = pickle.load(file)
    file.close()

    return new_obj

# %%
extracted_ref = read_from_file('extracted_ref')
extracted_spike = read_from_file('extracted_spike')
# Out:
# reading structures from pickle
# ------------------------------
# reading structures from pickle
# ------------------------------

# %%
extracted_ref['Spike'].keys()
# Out:
# ['HLA-C0602',
#  'HLA-A3101',
#  'HLA-C1502',
#  'HLA-B4501',
#  'HLA-B0702',
#  'HLA-C0702',
#  'HLA-C0701',
#  'HLA-B1801',
#  'HLA-B0801',
#  'HLA-C1402',
#  'HLA-B0803',
#  'HLA-B0802',
#  'HLA-C0401',
#  'HLA-B5401',
#  'HLA-B5101',
#  'HLA-A6801',
#  'HLA-A2402',
#  'HLA-A2403',
#  'HLA-B3503',
#  'HLA-A6802',
#  'HLA-A2501',
#  'HLA-A0212',
#  'HLA-A0211',
#  'HLA-A0217',
#  'HLA-A1101',
#  'HLA-E0101',
#  'HLA-A3215',
#  'HLA-B4001',
#  'HLA-A0219',
#  'HLA-B4002',
#  'HLA-B3801',
#  'HLA-B1402',
#  'HLA-B1517',
#  'HLA-B3901',
#  'HLA-B8301',
#  'HLA-B7301',
#  'HLA-B1502',
#  'HLA-A0101',
#  'HLA-B4801',
#  'HLA-A6901',
#  'HLA-B5801',
#  'HLA-C0501',
#  'HLA-A6823',
#  'HLA-B5802',
#  'HLA-B5701',
#  'HLA-A0250',
#  'HLA-C0303',
#  'HLA-A0202',
#  'HLA-A3002',
#  'HLA-A3001',
#  'HLA-B4403',
#  'HLA-A2301',
#  'HLA-B3501',
#  'HLA-A3301',
#  'HLA-C1203',
#  'HLA-B4402',
#  'HLA-B4601',
#  'HLA-A0216',
#  'HLA-A3201',
#  'HLA-A0205',
#  'HLA-A0206',
#  'HLA-A0207',
#  'HLA-A0201',
#  'HLA-A3207',
#  'HLA-A0203',
#  'HLA-A2602',
#  'HLA-A6601',
#  'HLA-B4201',
#  'HLA-A2601',
#  'HLA-A0301',
#  'HLA-C0802',
#  'HLA-A8001',
#  'HLA-B1503',
#  'HLA-B2705',
#  'HLA-B1501',
#  'HLA-B4013',
#  'HLA-A2603',
#  'HLA-B1509',
#  'HLA-B5301',
#  'HLA-B2720',
#  'HLA-A2902']

# %%
all_hla_binders = [extracted_ref['Spike'][key] for key in extracted_ref['Spike'].keys()] 
positions = []
for all_binders in all_hla_binders:
    for binder in all_binders: 
        positions.append(int(binder[0]))

# %%
positions
# Out:
# [326,
#  235,
#  452,
#  401,
#  903,
#  317,
#  1059,
#  455,
#  268,
#  575,
#  914,
#  903,
#  144,
#  998,
#  350,
#  344,
#  132,
#  353,
#  903,
#  204,
#  504,
#  29,
#  42,
#  897,
#  683,
#  950,
#  76,
#  35,
#  348,
#  457,
#  1098,
#  181,
#  557,
#  345,
#  149,
#  345,
#  236,
#  555,
#  263,
#  556,
#  347,
#  343,
#  32,
#  34,
#  344,
#  676,
#  309,
#  456,
#  453,
#  33,
#  447,
#  394,
#  442,
#  310,
#  1095,
#  443,
#  717,
#  733,
#  1095,
#  170,
#  633,
#  27,
#  118,
#  684,
#  258,
#  201,
#  508,
#  318,
#  92,
#  553,
#  776,
#  1180,
#  711,
#  1106,
#  232,
#  134,
#  1004,
#  436,
#  393,
#  416,
#  61,
#  696,
#  373,
#  1024,
#  690,
#  657,
#  885,
#  341,
#  897,
#  950,
#  814,
#  299,
#  154,
#  1015,
#  1070,
#  153,
#  617,
#  154,
#  279,
#  616,
#  866,
#  1015,
#  700,
#  1014,
#  1180,
#  152,
#  1070,
#  1014,
#  1015,
#  513,
#  1013,
#  652,
#  679,
#  679,
#  679,
#  678,
#  868,
#  37,
#  215,
#  713,
#  1051,
#  726,
#  680,
#  677,
#  455,
#  326,
#  185,
#  268,
#  452,
#  788,
#  1209,
#  77,
#  1108,
#  1094,
#  168,
#  235,
#  634,
#  144,
#  1207,
#  903,
#  504,
#  1086,
#  143,
#  897,
#  506,
#  488,
#  447,
#  344,
#  264,
#  503,
#  1136,
#  1100,
#  263,
#  19,
#  264,
#  264,
#  1,
#  76,
#  56,
#  454,
#  159,
#  35,
#  1208,
#  455,
#  132,
#  36,
#  1207,
#  326,
#  452,
#  235,
#  401,
#  268,
#  1059,
#  317,
#  575,
#  914,
#  903,
#  455,
#  27,
#  998,
#  683,
#  42,
#  360,
#  29,
#  144,
#  344,
#  504,
#  76,
#  143,
#  1209,
#  191,
#  788,
#  1094,
#  950,
#  327,
#  167,
#  152,
#  1205,
#  1205,
#  167,
#  1204,
#  1203,
#  1205,
#  866,
#  1205,
#  137,
#  514,
#  1204,
#  895,
#  1205,
#  1204,
#  866,
#  723,
#  1202,
#  1206,
#  152,
#  746,
#  1203,
#  387,
#  463,
#  130,
#  322,
#  514,
#  482,
#  341,
#  868,
#  233,
#  820,
#  897,
#  554,
#  268,
#  867,
#  241,
#  240,
#  832,
#  342,
#  679,
#  690,
#  352,
#  340,
#  994,
#  453,
#  232,
#  553,
#  900,
#  268,
#  868,
#  899,
#  901,
#  200,
#  143,
#  868,
#  690,
#  264,
#  885,
#  705,
#  143,
#  1066,
#  936,
#  504,
#  235,
#  45,
#  634,
#  1136,
#  950,
#  633,
#  159,
#  23,
#  142,
#  488,
#  141,
#  365,
#  506,
#  1,
#  143,
#  641,
#  166,
#  142,
#  143,
#  268,
#  503,
#  452,
#  167,
#  201,
#  471,
#  1094,
#  268,
#  832,
#  900,
#  961,
#  918,
#  455,
#  534,
#  1205,
#  868,
#  897,
#  1208,
#  1009,
#  504,
#  159,
#  391,
#  1061,
#  368,
#  532,
#  783,
#  268,
#  900,
#  185,
#  553,
#  897,
#  373,
#  268,
#  1208,
#  341,
#  455,
#  488,
#  750,
#  108,
#  1102,
#  832,
#  781,
#  1211,
#  1051,
#  918,
#  29,
#  532,
#  1136,
#  968,
#  641,
#  925,
#  488,
#  77,
#  167,
#  1235,
#  131,
#  166,
#  268,
#  754,
#  1216,
#  83,
#  192,
#  484,
#  886,
#  885,
#  1211,
#  1101,
#  256,
#  378,
#  132,
#  257,
#  504,
#  348,
#  83,
#  335,
#  335,
#  55,
#  334,
#  663,
#  1088,
#  726,
#  1051,
#  1061,
#  713,
#  1211,
#  1051,
#  58,
#  1088,
#  559,
#  328,
#  628,
#  83,
#  1211,
#  7,
#  1210,
#  83,
#  489,
#  424,
#  37,
#  512,
#  558,
#  559,
#  726,
#  80,
#  82,
#  489,
#  1088,
#  54,
#  629,
#  55,
#  921,
#  7,
#  711,
#  424,
#  559,
#  1211,
#  83,
#  726,
#  1051,
#  713,
#  55,
#  1224,
#  6,
#  1088,
#  1051,
#  860,
#  328,
#  901,
#  223,
#  897,
#  23,
#  55,
#  223,
#  895,
#  7,
#  704,
#  717,
#  1211,
#  489,
#  704,
#  1224,
#  369,
#  346,
#  368,
#  1236,
#  399,
#  1097,
#  393,
#  1172,
#  34,
#  755,
#  1063,
#  1098,
#  724,
#  87,
#  257,
#  567,
#  346,
#  448,
#  636,
#  1210,
#  367,
#  1207,
#  1207,
#  634,
#  158,
#  487,
#  447,
#  633,
#  1209,
#  896,
#  488,
#  1208,
#  1210,
#  1206,
#  1204,
#  1210,
#  1205,
#  1205,
#  366,
#  1209,
#  264,
#  365,
#  367,
#  263,
#  634,
#  367,
#  1206,
#  1204,
#  897,
#  1207,
#  366,
#  311,
#  1065,
#  267,
#  264,
#  157,
#  1207,
#  327,
#  1210,
#  506,
#  349,
#  156,
#  158,
#  446,
#  1208,
#  1206,
#  158,
#  394,
#  143,
#  447,
#  202,
#  1215,
#  486,
#  326,
#  787,
#  368,
#  36,
#  632,
#  157,
#  485,
#  487,
#  327,
#  631,
#  444,
#  143,
#  488,
#  1207,
#  634,
#  447,
#  705,
#  754,
#  487,
#  77,
#  267,
#  378,
#  1136,
#  368,
#  557,
#  327,
#  57,
#  487,
#  264,
#  367,
#  486,
#  487,
#  443,
#  506,
#  835,
#  485,
#  1100,
#  487,
#  263,
#  267,
#  264,
#  486,
#  1094,
#  1215,
#  897,
#  1204,
#  192,
#  672,
#  1207,
#  263,
#  345,
#  925,
#  328,
#  328,
#  328,
#  327,
#  326,
#  327,
#  895,
#  1261,
#  1051,
#  83,
#  55,
#  167,
#  489,
#  1051,
#  1050,
#  215,
#  328,
#  167,
#  185,
#  23,
#  1,
#  1211,
#  489,
#  55,
#  37,
#  293,
#  54,
#  37,
#  895,
#  791,
#  54,
#  257,
#  717,
#  733,
#  776,
#  1219,
#  885,
#  872,
#  27,
#  373,
#  1167,
#  339,
#  391,
#  703,
#  716,
#  258,
#  1094,
#  567,
#  901,
#  717,
#  730,
#  872,
#  1120,
#  880,
#  657,
#  586,
#  1049,
#  1049,
#  717,
#  613,
#  537,
#  60,
#  393,
#  881,
#  256,
#  868,
#  483,
#  868,
#  61,
#  585,
#  939,
#  341,
#  643,
#  255,
#  339,
#  297,
#  191,
#  868,
#  1187,
#  1094,
#  257,
#  690,
#  747,
#  214,
#  365,
#  1,
#  567,
#  1187,
#  1112,
#  939,
#  779,
#  391,
#  49,
#  1187,
#  864,
#  190,
#  1187,
#  872,
#  1167,
#  1186,
#  791,
#  867,
#  1186,
#  1185,
#  1228,
#  717,
#  750,
#  268,
#  982,
#  132,
#  1219,
#  1191,
#  999,
#  1061,
#  914,
#  648,
#  776,
#  611,
#  416,
#  900,
#  785,
#  515,
#  752,
#  914,
#  982,
#  975,
#  999,
#  1219,
#  268,
#  61,
#  1095,
#  132,
#  1184,
#  1,
#  1061,
#  201,
#  1216,
#  99,
#  268,
#  690,
#  1094,
#  1,
#  868,
#  267,
#  1214,
#  268,
#  1208,
#  689,
#  132,
#  710,
#  416,
#  868,
#  690,
#  712,
#  221,
#  169,
#  867,
#  514,
#  723,
#  88,
#  1236,
#  369,
#  368,
#  1019,
#  814,
#  825,
#  453,
#  813,
#  300,
#  722,
#  366,
#  374,
#  1064,
#  721,
#  938,
#  1195,
#  301,
#  974,
#  815,
#  816,
#  826,
#  268,
#  756,
#  141,
#  170,
#  910,
#  724,
#  549,
#  1235,
#  1018,
#  347,
#  909,
#  268,
#  269,
#  266,
#  266,
#  265,
#  504,
#  268,
#  268,
#  268,
#  267,
#  267,
#  267,
#  268,
#  502,
#  502,
#  505,
#  501,
#  1136,
#  1209,
#  319,
#  319,
#  319,
#  319,
#  1205,
#  897,
#  1211,
#  1049,
#  1,
#  49,
#  1207,
#  344,
#  1094,
#  483,
#  885,
#  55,
#  895,
#  365,
#  868,
#  1208,
#  1209,
#  717,
#  268,
#  879,
#  59,
#  191,
#  31,
#  166,
#  165,
#  56,
#  201,
#  143,
#  690,
#  420,
#  371,
#  368,
#  217,
#  1208,
#  83,
#  1208,
#  132,
#  31,
#  899,
#  1015,
#  482,
#  167,
#  338,
#  1014,
#  1255,
#  481,
#  130,
#  480,
#  132,
#  975,
#  999,
#  1219,
#  1120,
#  268,
#  1191,
#  1235,
#  1095,
#  914,
#  1216,
#  515,
#  943,
#  1059,
#  761,
#  3,
#  108,
#  1201,
#  151,
#  1184,
#  1208,
#  1216,
#  258,
#  982,
#  482,
#  167,
#  154,
#  514,
#  481,
#  463,
#  480,
#  1180,
#  482,
#  1015,
#  514,
#  167,
#  130,
#  482,
#  481,
#  166,
#  322,
#  296,
#  189,
#  132,
#  47,
#  44,
#  45,
#  1157,
#  45,
#  1213,
#  1213,
#  642,
#  235,
#  1212,
#  885,
#  852,
#  46,
#  326,
#  48,
#  422,
#  632,
#  344,
#  235,
#  995,
#  452,
#  341,
#  486,
#  232,
#  326,
#  1,
#  39,
#  678,
#  1086,
#  214,
#  504,
#  268,
#  868,
#  1152,
#  953,
#  344,
#  108,
#  900,
#  1003,
#  1043,
#  763,
#  814,
#  159,
#  257,
#  1004,
#  885,
#  864,
#  684,
#  365,
#  879,
#  732,
#  824,
#  371,
#  897,
#  711,
#  1053,
#  303,
#  1049,
#  391,
#  191,
#  508,
#  49,
#  211,
#  1247,
#  1228,
#  589,
#  717,
#  1064,
#  235,
#  885,
#  763,
#  868,
#  344,
#  504,
#  690,
#  688,
#  1051,
#  132,
#  936,
#  317,
#  852,
#  59,
#  1,
#  642,
#  1211,
#  895,
#  23,
#  713,
#  270,
#  83,
#  519,
#  249,
#  55,
#  228,
#  477,
#  868,
#  629,
#  424,
#  207,
#  860,
#  1055,
#  897,
#  1261,
#  461,
#  679,
#  37,
#  49,
#  320,
#  805,
#  810,
#  903,
#  1205,
#  1211,
#  1210,
#  167,
#  1211,
#  1211,
#  344,
#  903,
#  632,
#  561,
#  902,
#  903,
#  901,
#  1213,
#  156,
#  1205,
#  903,
#  902,
#  200,
#  763,
#  1209,
#  154,
#  235,
#  1204,
#  1105,
#  1203,
#  1205,
#  1205,
#  1204,
#  1206,
#  353,
#  344,
#  903,
#  76,
#  1214,
#  1211,
#  627,
#  ...]

# %%
f = plt.hist(positions, bins=50)
plt.title('Position of Strong-binding peptides to reference Spike')
plt.show()
